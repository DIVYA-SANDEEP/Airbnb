# %%
import pandas as pd
import numpy as np
import pymongo
import seaborn as sns
import matplotlib.pyplot as plt
import json
import openpyxl

# %%
from pymongo.mongo_client import MongoClient
client = MongoClient("mongodb+srv://divya:1234@cluster0.afrzrns.mongodb.net/?retryWrites=true&w=majority")
database = client.Airbnb
collection = database.Airbnb_Data

# %%
"""
with open(r"C:\Users\Divya\Desktop\Python-Guvi\Project\Airbnb\sample_airbnb.json") as file:
    data = json.load(file)
    if isinstance(data, list):
        collection.insert_many(data)
    else:
        collection.insert_one(data)
        
"""

# %%
airbnb_data = []
for i in collection.find():
    data = dict(Id = i['_id'],
Listing_url = i['listing_url'],
Name = i.get('name'),
Description = i['description'],
House_rules = i.get('house_rules'),
Property_type = i['property_type'],
Room_type = i['room_type'],
Bed_type = i['bed_type'],
Min_nights = int(i['minimum_nights']),
Max_nights = int(i['maximum_nights']),
Cancellation_policy = i['cancellation_policy'],
Accomodates = i['accommodates'],
Total_bedrooms = i.get('bedrooms'),
Total_beds = i.get('beds'),
Availability_365 = i['availability']['availability_365'],
Availability_90 = i['availability']['availability_90'],
Availability_60 = i['availability']['availability_60'],
Availability_30 = i['availability']['availability_30'],
Price = i['price'],
Security_deposit = i.get('security_deposit'),
Cleaning_fee = i.get('cleaning_fee'),
Extra_people = i['extra_people'],
Guests_included= i['guests_included'],
No_of_reviews = i['number_of_reviews'],
Review_scores = i['review_scores'].get('review_scores_rating'),
Amenities = ', '.join(i['amenities']),
Host_id = i['host']['host_id'],
Host_name = i['host']['host_name'],
Street = i['address']['street'],
Country = i['address']['country'],
Country_code = i['address']['country_code'],
Location_type = i['address']['location']['type'],
Longitude = i['address']['location']['coordinates'][0],
Latitude = i['address']['location']['coordinates'][1],
Is_location_exact = i['address']['location']['is_location_exact'],
Host_Location= i['host']['host_location'],    
Review_score = i['review_scores'].get('review_scores_value')
    )
    airbnb_data.append(data)

# %%
df =pd.DataFrame(airbnb_data)
df
# Out:
#             Id                            Listing_url  \
# 0     10140368  https://www.airbnb.com/rooms/10140368
# 1     10112159  https://www.airbnb.com/rooms/10112159
# 2     10059872  https://www.airbnb.com/rooms/10059872
# 3     10084023  https://www.airbnb.com/rooms/10084023
# 4     10091713  https://www.airbnb.com/rooms/10091713
# ...        ...                                    ...
# 5550   9907907   https://www.airbnb.com/rooms/9907907
# 5551   9951865   https://www.airbnb.com/rooms/9951865
# 5552   9990304   https://www.airbnb.com/rooms/9990304
# 5553   9969335   https://www.airbnb.com/rooms/9969335
# 5554   9993190   https://www.airbnb.com/rooms/9993190
#
#                                                    Name  \
# 0                          A bedroom far away from home
# 1                   Downtown Oporto Inn (room cleaning)
# 2                    Soho Cozy, Spacious and Convenient
# 3                     City center private room with bed
# 4      Surry Hills Studio - Your Perfect Base in Sydney
# ...                                                 ...
# 5550                         Large double room in Bondi
# 5551                                       Quarto Legal
# 5552     March Madness Special! Aina Nalu Platinum D107
# 5553                 Central, Modern, University, Metro
# 5554  Just Steps from the Ocean at Premier Platinum ...
#
#                                             Description  \
# 0     NOTES: BEFORE BOOKING, PLEASE KNOW THAT WE ARE...
# 1     Tradicional building, with high ceilings next ...
# 2     Clean, fully furnish, Spacious 1 bedroom flat ...
# 3     House is located 5mins walk from Sham Shui Po ...
# 4     This spacious, light filled studio has everyth...
# ...                                                 ...
# 5550  A bright large double room is available in a b...
# 5551  Meu espaço é perto de Cristo Redentor, Copacab...
# 5552  Walk out to Saltwater Infinity Pool! Call us N...
# 5553  Welcome to this completely new apartment and f...
# 5554  Relax Hawaiian Style in Gated Community on Oce...
#
#                                             House_rules Property_type  \
# 0     No shoes allowed inside the apartment. Be poli...     Apartment
# 1     Devem respeitar o descanso dos restantes hóspe...        Hostel
# 2                                                           Apartment
# 3     1. 禁止吸煙, 只限女生入住 (除得到批准) No smoking and only fe...    Guesthouse
# 4     No smoking:  No smoking any substance, includi...     Apartment
# ...                                                 ...           ...
# 5550  We like to keep the flat clean and tidy so wou...     Apartment
# 5551                                                        Apartment
# 5552  As a guest of Coconut Condos, I agree to the f...   Condominium
# 5553                                                        Apartment
# 5554  As a guest of Coconut Condos, I agree to the f...     Townhouse
#
#             Room_type  Bed_type  Min_nights  Max_nights  ...       Host_name  \
# 0        Private room  Real Bed           1          10  ...            Lane
# 1        Private room  Real Bed           1        1125  ...       Elisabete
# 2     Entire home/apt  Real Bed           4          20  ...        Giovanni
# 3        Private room     Futon           1         500  ...              Yi
# 4     Entire home/apt  Real Bed          10          21  ...             Ben
# ...               ...       ...         ...         ...  ...             ...
# 5550     Private room  Real Bed           3        1125  ...            Lucy
# 5551     Private room  Real Bed           2          15  ...         Dailton
# 5552  Entire home/apt  Real Bed           3         365  ...  Coconut Condos
# 5553  Entire home/apt  Real Bed           6          60  ...  Daniel & Maria
# 5554  Entire home/apt  Real Bed           3         365  ...  Coconut Condos
#
#                                                Street        Country  \
# 0                           Queens, NY, United States  United States
# 1                              Porto, Porto, Portugal       Portugal
# 2              Hong Kong, Hong Kong Island, Hong Kong      Hong Kong
# 3                           Hong Kong , 九龍, Hong Kong      Hong Kong
# 4                         Surry Hills, NSW, Australia      Australia
# ...                                               ...            ...
# 5550                      Bondi Beach, NSW, Australia      Australia
# 5551  Rio de Janeiro, State of Rio de Janeiro, Brazil         Brazil
# 5552                       Lahaina, HI, United States  United States
# 5553                           Porto, Porto, Portugal       Portugal
# 5554                       Lahaina, HI, United States  United States
#
#       Country_code  Location_type   Longitude   Latitude  Is_location_exact  \
# 0               US          Point  -73.822570  40.714850               True
# 1               PT          Point   -8.608670  41.154300              False
# 2               HK          Point  114.150270  22.281580               True
# 3               HK          Point  114.166900  22.331400               True
# 4               AU          Point  151.215540 -33.880290               True
# ...            ...            ...         ...        ...                ...
# 5550            AU          Point  151.265420 -33.892980              False
# 5551            BR          Point  -43.210667 -22.918155              False
# 5552            US          Point -156.676460  20.875610              False
# 5553            PT          Point   -8.604640  41.159080               True
# 5554            US          Point -156.667520  20.858940              False
#
#                                         Host_Location  Review_score
# 0                                                  US          10.0
# 1                              Porto, Porto, Portugal           NaN
# 2                                Hong Kong, Hong Kong           8.0
# 3                                       United States          10.0
# 4                          New South Wales, Australia           9.0
# ...                                               ...           ...
# 5550          Bondi Beach, New South Wales, Australia           NaN
# 5551  Rio de Janeiro, State of Rio de Janeiro, Brazil          10.0
# 5552                   Lahaina, Hawaii, United States           9.0
# 5553                           Porto, Porto, Portugal          10.0
# 5554                   Lahaina, Hawaii, United States           9.0
#
# [5555 rows x 37 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 37 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   5555 non-null   object
#  1   Listing_url          5555 non-null   object
#  2   Name                 5555 non-null   object
#  3   Description          5555 non-null   object
#  4   House_rules          5555 non-null   object
#  5   Property_type        5555 non-null   object
#  6   Room_type            5555 non-null   object
#  7   Bed_type             5555 non-null   object
#  8   Min_nights           5555 non-null   int64
#  9   Max_nights           5555 non-null   int64
#  10  Cancellation_policy  5555 non-null   object
#  11  Accomodates          5555 non-null   int64
#  12  Total_bedrooms       5550 non-null   float64
#  13  Total_beds           5542 non-null   float64
#  14  Availability_365     5555 non-null   int64
#  15  Availability_90      5555 non-null   int64
#  16  Availability_60      5555 non-null   int64
#  17  Availability_30      5555 non-null   int64
#  18  Price                5555 non-null   float64
#  19  Security_deposit     3471 non-null   float64
#  20  Cleaning_fee         4024 non-null   float64
#  21  Extra_people         5555 non-null   float64
#  22  Guests_included      5555 non-null   float64
#  23  No_of_reviews        5555 non-null   int64
#  24  Review_scores        4081 non-null   float64
#  25  Amenities            5555 non-null   object
#  26  Host_id              5555 non-null   object
#  27  Host_name            5555 non-null   object
#  28  Street               5555 non-null   object
#  29  Country              5555 non-null   object
#  30  Country_code         5555 non-null   object
#  31  Location_type        5555 non-null   object
#  32  Longitude            5555 non-null   float64
#  33  Latitude             5555 non-null   float64
#  34  Is_location_exact    5555 non-null   bool
#  35  Host_Location        5555 non-null   object
#  36  Review_score         4080 non-null   float64
# dtypes: bool(1), float64(11), int64(8), object(17)
# memory usage: 1.5+ MB

# %%
df.Price = df.Price.astype(str).astype(float)
df.Security_deposit = df.Security_deposit[~df.Security_deposit.isna()].astype(str).astype(float)
df.Cleaning_fee = df.Cleaning_fee[~df.Cleaning_fee.isna()].astype(str).astype(float)
df.Extra_people = df.Extra_people.astype(str).astype(float)
df.Guests_included = df.Guests_included.astype(str).astype(float)
df.Review_scores = df.Review_scores.astype(float).astype("Int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 37 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   5555 non-null   object
#  1   Listing_url          5555 non-null   object
#  2   Name                 5555 non-null   object
#  3   Description          5555 non-null   object
#  4   House_rules          5555 non-null   object
#  5   Property_type        5555 non-null   object
#  6   Room_type            5555 non-null   object
#  7   Bed_type             5555 non-null   object
#  8   Min_nights           5555 non-null   int64
#  9   Max_nights           5555 non-null   int64
#  10  Cancellation_policy  5555 non-null   object
#  11  Accomodates          5555 non-null   int64
#  12  Total_bedrooms       5550 non-null   float64
#  13  Total_beds           5542 non-null   float64
#  14  Availability_365     5555 non-null   int64
#  15  Availability_90      5555 non-null   int64
#  16  Availability_60      5555 non-null   int64
#  17  Availability_30      5555 non-null   int64
#  18  Price                5555 non-null   float64
#  19  Security_deposit     3471 non-null   float64
#  20  Cleaning_fee         4024 non-null   float64
#  21  Extra_people         5555 non-null   float64
#  22  Guests_included      5555 non-null   float64
#  23  No_of_reviews        5555 non-null   int64
#  24  Review_scores        4081 non-null   Int64
#  25  Amenities            5555 non-null   object
#  26  Host_id              5555 non-null   object
#  27  Host_name            5555 non-null   object
#  28  Street               5555 non-null   object
#  29  Country              5555 non-null   object
#  30  Country_code         5555 non-null   object
#  31  Location_type        5555 non-null   object
#  32  Longitude            5555 non-null   float64
#  33  Latitude             5555 non-null   float64
#  34  Is_location_exact    5555 non-null   bool
#  35  Host_Location        5555 non-null   object
#  36  Review_score         4080 non-null   float64
# dtypes: Int64(1), bool(1), float64(10), int64(8), object(17)
# memory usage: 1.5+ MB

# %%
df.isnull().sum()
# Out:
# Id                        0
# Listing_url               0
# Name                      0
# Description               0
# House_rules               0
# Property_type             0
# Room_type                 0
# Bed_type                  0
# Min_nights                0
# Max_nights                0
# Cancellation_policy       0
# Accomodates               0
# Total_bedrooms            5
# Total_beds               13
# Availability_365          0
# Availability_90           0
# Availability_60           0
# Availability_30           0
# Price                     0
# Security_deposit       2084
# Cleaning_fee           1531
# Extra_people              0
# Guests_included           0
# No_of_reviews             0
# Review_scores          1474
# Amenities                 0
# Host_id                   0
# Host_name                 0
# Street                    0
# Country                   0
# Country_code              0
# Location_type             0
# Longitude                 0
# Latitude                  0
# Is_location_exact         0
# Host_Location             0
# Review_score           1475
# dtype: int64

# %%
df.Total_bedrooms.fillna(df.Total_bedrooms.mode()[0],inplace=True)
# Out:
# C:\Users\Divya\AppData\Local\Temp\ipykernel_9808\2819310503.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Total_bedrooms.fillna(df.Total_bedrooms.mode()[0],inplace=True)

# %%
df.Total_beds.fillna(df.Total_beds.median(),inplace=True)
df.Security_deposit.fillna(df.Security_deposit.median(),inplace=True)
df.Cleaning_fee.fillna(df.Cleaning_fee.median(),inplace=True)
df.Review_scores.fillna(df.Review_scores.median(),inplace=True)
# Out:
# C:\Users\Divya\AppData\Local\Temp\ipykernel_9808\254135065.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Total_beds.fillna(df.Total_beds.median(),inplace=True)
# C:\Users\Divya\AppData\Local\Temp\ipykernel_9808\254135065.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Security_deposit.fillna(df.Security_deposit.median(),inplace=True)
# C:\Users\Divya\AppData\Local\Temp\ipykernel_9808\254135065.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Cleaning_fee.fillna(df.Cleaning_fee.median(),inplace=True)
# C:\Users\Divya\AppData\Local\Temp\ipykernel_9808\254135065.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Review_scores.fillna(df.Review_scores.median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Id                        0
# Listing_url               0
# Name                      0
# Description               0
# House_rules               0
# Property_type             0
# Room_type                 0
# Bed_type                  0
# Min_nights                0
# Max_nights                0
# Cancellation_policy       0
# Accomodates               0
# Total_bedrooms            0
# Total_beds                0
# Availability_365          0
# Availability_90           0
# Availability_60           0
# Availability_30           0
# Price                     0
# Security_deposit          0
# Cleaning_fee              0
# Extra_people              0
# Guests_included           0
# No_of_reviews             0
# Review_scores             0
# Amenities                 0
# Host_id                   0
# Host_name                 0
# Street                    0
# Country                   0
# Country_code              0
# Location_type             0
# Longitude                 0
# Latitude                  0
# Is_location_exact         0
# Host_Location             0
# Review_score           1475
# dtype: int64

# %%
df.Description.replace(to_replace='',value='No Description Provided',inplace=True)
df.House_rules.replace(to_replace='',value='No House rules Provided',inplace=True)
df.Amenities.replace(to_replace='',value='Not Available',inplace=True)
# Out:
# C:\Users\Divya\AppData\Local\Temp\ipykernel_9808\366845729.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Description.replace(to_replace='',value='No Description Provided',inplace=True)
# C:\Users\Divya\AppData\Local\Temp\ipykernel_9808\366845729.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.House_rules.replace(to_replace='',value='No House rules Provided',inplace=True)
# C:\Users\Divya\AppData\Local\Temp\ipykernel_9808\366845729.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Amenities.replace(to_replace='',value='Not Available',inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Id, Listing_url, Name, Description, House_rules, Property_type, Room_type, Bed_type, Min_nights, Max_nights, Cancellation_policy, Accomodates, Total_bedrooms, Total_beds, Availability_365, Availability_90, Availability_60, Availability_30, Price, Security_deposit, Cleaning_fee, Extra_people, Guests_included, No_of_reviews, Review_scores, Amenities, Host_id, Host_name, Street, Country, Country_code, Location_type, Longitude, Latitude, Is_location_exact, Host_Location, Review_score]
# Index: []
#
# [0 rows x 37 columns]

# %%
df.drop(labels=list(df[df.Name.duplicated(keep=False)].index),inplace=True)
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#             Id                            Listing_url  \
# 0     10140368  https://www.airbnb.com/rooms/10140368
# 1     10112159  https://www.airbnb.com/rooms/10112159
# 2     10059872  https://www.airbnb.com/rooms/10059872
# 3     10084023  https://www.airbnb.com/rooms/10084023
# 4     10091713  https://www.airbnb.com/rooms/10091713
# ...        ...                                    ...
# 5524   9907907   https://www.airbnb.com/rooms/9907907
# 5525   9951865   https://www.airbnb.com/rooms/9951865
# 5526   9990304   https://www.airbnb.com/rooms/9990304
# 5527   9969335   https://www.airbnb.com/rooms/9969335
# 5528   9993190   https://www.airbnb.com/rooms/9993190
#
#                                                    Name  \
# 0                          A bedroom far away from home
# 1                   Downtown Oporto Inn (room cleaning)
# 2                    Soho Cozy, Spacious and Convenient
# 3                     City center private room with bed
# 4      Surry Hills Studio - Your Perfect Base in Sydney
# ...                                                 ...
# 5524                         Large double room in Bondi
# 5525                                       Quarto Legal
# 5526     March Madness Special! Aina Nalu Platinum D107
# 5527                 Central, Modern, University, Metro
# 5528  Just Steps from the Ocean at Premier Platinum ...
#
#                                             Description  \
# 0     NOTES: BEFORE BOOKING, PLEASE KNOW THAT WE ARE...
# 1     Tradicional building, with high ceilings next ...
# 2     Clean, fully furnish, Spacious 1 bedroom flat ...
# 3     House is located 5mins walk from Sham Shui Po ...
# 4     This spacious, light filled studio has everyth...
# ...                                                 ...
# 5524  A bright large double room is available in a b...
# 5525  Meu espaço é perto de Cristo Redentor, Copacab...
# 5526  Walk out to Saltwater Infinity Pool! Call us N...
# 5527  Welcome to this completely new apartment and f...
# 5528  Relax Hawaiian Style in Gated Community on Oce...
#
#                                             House_rules Property_type  \
# 0     No shoes allowed inside the apartment. Be poli...     Apartment
# 1     Devem respeitar o descanso dos restantes hóspe...        Hostel
# 2                               No House rules Provided     Apartment
# 3     1. 禁止吸煙, 只限女生入住 (除得到批准) No smoking and only fe...    Guesthouse
# 4     No smoking:  No smoking any substance, includi...     Apartment
# ...                                                 ...           ...
# 5524  We like to keep the flat clean and tidy so wou...     Apartment
# 5525                            No House rules Provided     Apartment
# 5526  As a guest of Coconut Condos, I agree to the f...   Condominium
# 5527                            No House rules Provided     Apartment
# 5528  As a guest of Coconut Condos, I agree to the f...     Townhouse
#
#             Room_type  Bed_type  Min_nights  Max_nights  ...       Host_name  \
# 0        Private room  Real Bed           1          10  ...            Lane
# 1        Private room  Real Bed           1        1125  ...       Elisabete
# 2     Entire home/apt  Real Bed           4          20  ...        Giovanni
# 3        Private room     Futon           1         500  ...              Yi
# 4     Entire home/apt  Real Bed          10          21  ...             Ben
# ...               ...       ...         ...         ...  ...             ...
# 5524     Private room  Real Bed           3        1125  ...            Lucy
# 5525     Private room  Real Bed           2          15  ...         Dailton
# 5526  Entire home/apt  Real Bed           3         365  ...  Coconut Condos
# 5527  Entire home/apt  Real Bed           6          60  ...  Daniel & Maria
# 5528  Entire home/apt  Real Bed           3         365  ...  Coconut Condos
#
#                                                Street        Country  \
# 0                           Queens, NY, United States  United States
# 1                              Porto, Porto, Portugal       Portugal
# 2              Hong Kong, Hong Kong Island, Hong Kong      Hong Kong
# 3                           Hong Kong , 九龍, Hong Kong      Hong Kong
# 4                         Surry Hills, NSW, Australia      Australia
# ...                                               ...            ...
# 5524                      Bondi Beach, NSW, Australia      Australia
# 5525  Rio de Janeiro, State of Rio de Janeiro, Brazil         Brazil
# 5526                       Lahaina, HI, United States  United States
# 5527                           Porto, Porto, Portugal       Portugal
# 5528                       Lahaina, HI, United States  United States
#
#       Country_code  Location_type   Longitude   Latitude  Is_location_exact  \
# 0               US          Point  -73.822570  40.714850               True
# 1               PT          Point   -8.608670  41.154300              False
# 2               HK          Point  114.150270  22.281580               True
# 3               HK          Point  114.166900  22.331400               True
# 4               AU          Point  151.215540 -33.880290               True
# ...            ...            ...         ...        ...                ...
# 5524            AU          Point  151.265420 -33.892980              False
# 5525            BR          Point  -43.210667 -22.918155              False
# 5526            US          Point -156.676460  20.875610              False
# 5527            PT          Point   -8.604640  41.159080               True
# 5528            US          Point -156.667520  20.858940              False
#
#                                         Host_Location  Review_score
# 0                                                  US          10.0
# 1                              Porto, Porto, Portugal           NaN
# 2                                Hong Kong, Hong Kong           8.0
# 3                                       United States          10.0
# 4                          New South Wales, Australia           9.0
# ...                                               ...           ...
# 5524          Bondi Beach, New South Wales, Australia           NaN
# 5525  Rio de Janeiro, State of Rio de Janeiro, Brazil          10.0
# 5526                   Lahaina, Hawaii, United States           9.0
# 5527                           Porto, Porto, Portugal          10.0
# 5528                   Lahaina, Hawaii, United States           9.0
#
# [5529 rows x 37 columns]

# %%
df.to_csv('Airbnb_data.csv',index=False)

# %%
df.to_excel('Airbnb_Data.xlsx', sheet_name='Airbnb', index=False, engine='openpyxl')
